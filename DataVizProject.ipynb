# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('inputs/Sleep Log - Ali .csv')
df1
# Out:
#                  Date  Sleep Start  Sleep End Total Hours of Sleep  \
# 0   Wednesday, 29 Mar   2:00:00 AM  5:00:00AM              3:00:00
# 1    Thursday, 30 Mar   2:00:00 AM  7:00:00AM              5:00:00
# 2      Friday, 31 Mar  11:00:00 PM  4:00:00AM              5:00:00
# 3       Monday, 3 Apr  12:00:00 AM  3:00:00AM              3:00:00
# 4      Tuesday, 4 Apr  11:00:00 PM  4:00:00AM              5:00:00
# 5    Wednesday, 5 Apr  11:30:00 PM  2:30:00AM              3:00:00
# 6     Thursday, 6 Apr  12:30:00 AM  3:00:00AM              2:30:00
# 7       Friday, 7 Apr  11:30:00 PM  3:30:00AM              4:00:00
# 8      Monday, 10 Apr  10:30:00 PM  2:30:00AM              4:00:00
# 9     Tuesday, 11 Apr  11:30:00 PM  4:00:00AM              4:30:00
# 10  Wednesday, 12 Apr  11:30:00 PM  3:00:00AM              3:30:00
#
#     Quality rating  Daily Productivity Rating                         Notes
# 0                2                          3  Stay up late for school work
# 1                3                          2  Stay up late for school work
# 2                4                          2                           NaN
# 3                4                          4                           NaN
# 4                4                          2                           NaN
# 5                4                          3                           NaN
# 6                3                          4                           NaN
# 7                4                          5                           NaN
# 8                4                          5                           NaN
# 9                4                          4                           NaN
# 10               4                          5                           NaN

# %%
# Creating a bubble plot. Demonstrating Daily Productivity rating given hours sleep and sleep quality
x = df1['Total Hours of Sleep'].sort_values(ascending=True)
y = df1['Quality rating'].sort_values(ascending=True)
z = df1['Daily Productivity Rating']


plt.scatter(x, y.sort_values(ascending=True), s=z*1000, c="red", alpha=0.4)
plt.show()

# %%
df2 = pd.read_csv('inputs/Sleep Log - Anupriya.csv')
df2
# Out:
#                  Date  Sleep Start  Sleep End Total Hours of Sleep  \
# 0   Wednesday, 29 Mar   1:00:00 AM  8:00:00AM              7:00:00
# 1    Thursday, 30 Mar   2:00:00 AM  8:00:00AM              6:00:00
# 2      Friday, 31 Mar  12:00:00 AM  8:00:00AM              8:00:00
# 3       Monday, 3 Apr   1:00:00 AM  8:00:00AM              7:00:00
# 4      Tuesday, 4 Apr   1:00:00 AM  8:00:00AM              7:00:00
# 5    Wednesday, 5 Apr  12:00:00 AM  8:00:00AM              8:00:00
# 6     Thursday, 6 Apr  12:30:00 AM  8:45:00AM              8:15:00
# 7       Friday, 7 Apr  11:30:00 PM  8:00:00AM              8:30:00
# 8      Monday, 10 Apr  10:30:00 PM  8:00:00AM              9:30:00
# 9     Tuesday, 11 Apr  11:30:00 PM  8:00:00AM              8:30:00
# 10  Wednesday, 12 Apr   1:30:00 AM  8:50:00AM              7:20:00
#
#     Quality rating  Daily Productivity Rating  \
# 0                4                          3
# 1                3                          2
# 2                4                          4
# 3                4                          2
# 4                5                          4
# 5                3                          2
# 6                3                          1
# 7                4                          3
# 8                5                          3
# 9                4                          4
# 10               4                          2
#
#                                                 Notes
# 0                                                 NaN
# 1   Drank too much caffine so I stayed up late wor...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   Was really anxious not sure why but it labotom...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN

# %%
# Creating a bubble plot. Demonstrating Daily Productivity rating given hours sleep and sleep quality
x = df2['Total Hours of Sleep'].sort_values(ascending=True)
y = df2['Quality rating'].sort_values(ascending=True)
z = df2['Daily Productivity Rating']


plt.scatter(x, y, s=z*1000, c="blue", alpha=0.4)
plt.show()
